# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

df = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn-selected-columns.csv")

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\nivet\OneDrive\apexplanet-data-analytics\notebooks

# %%
import os

print(os.listdir("../data/raw"))
# Out:
# ['WA_Fn-UseC_-Telco-Customer-Churn-selected-columns.csv']

# %%
import pandas as pd

df = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn-selected-columns.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity
# 0  No phone service             DSL             No
# 1                No             DSL            Yes
# 2                No             DSL            Yes
# 3  No phone service             DSL            Yes
# 4                No     Fiber optic             No

# %%
df.shape
# Out:
# (7043, 10)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customerID       7043 non-null   str
#  1   gender           7043 non-null   str
#  2   SeniorCitizen    7043 non-null   int64
#  3   Partner          7043 non-null   str
#  4   Dependents       7043 non-null   str
#  5   tenure           7043 non-null   int64
#  6   PhoneService     7043 non-null   str
#  7   MultipleLines    7043 non-null   str
#  8   InternetService  7043 non-null   str
#  9   OnlineSecurity   7043 non-null   str
# dtypes: int64(2), str(8)
# memory usage: 550.4 KB

# %%
df.isnull().sum()
# Out:
# customerID         0
# gender             0
# SeniorCitizen      0
# Partner            0
# Dependents         0
# tenure             0
# PhoneService       0
# MultipleLines      0
# InternetService    0
# OnlineSecurity     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure
# count    7043.000000  7043.000000
# mean        0.162147    32.371149
# std         0.368612    24.559481
# min         0.000000     0.000000
# 25%         0.000000     9.000000
# 50%         0.000000    29.000000
# 75%         0.000000    55.000000
# max         1.000000    72.000000

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\nivet\AppData\Local\Programs\Python\Python311\python.exe

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
print("Seaborn installed successfully!")
# Out:
# Seaborn installed successfully!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df["tenure"], bins=20, kde=True)

plt.title("Distribution of Customer Tenure")
plt.xlabel("Tenure (Months)")
plt.ylabel("Number of Customers")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
#       3
# ----> 4 sns.histplot(df["tenure"], bins=20, kde=True)
#       5
#       6 plt.title("Distribution of Customer Tenure")
#       7 plt.xlabel("Tenure (Months)")
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn-selected-columns.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity
# 0  No phone service             DSL             No
# 1                No             DSL            Yes
# 2                No             DSL            Yes
# 3  No phone service             DSL            Yes
# 4                No     Fiber optic             No

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df["tenure"], bins=20, kde=True)

plt.title("Distribution of Customer Tenure")
plt.xlabel("Tenure (Months)")
plt.ylabel("Number of Customers")

plt.show()

# %%
sns.countplot(x="gender", data=df)

plt.title("Customer Distribution by Gender")
plt.show()

# %%
sns.countplot(x="SeniorCitizen", data=df)

plt.title("Senior Citizen Distribution")
plt.xlabel("0 = No, 1 = Yes")

plt.show()

# %%
sns.countplot(x="InternetService", data=df)

plt.title("Internet Service Distribution")
plt.xticks(rotation=15)

plt.show()

# %%
sns.countplot(x="OnlineSecurity", data=df)

plt.title("Online Security Service")
plt.xticks(rotation=15)

plt.show()

# %%
df.describe(include="all")
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     7590-VHVEG   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.371149
# std            NaN    NaN       0.368612     NaN        NaN    24.559481
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity
# ...

# %% [markdown]
# ## Insight 5
#
# The chart shows how many customers have subscribed to online security services and how many have not.

# %%
df.to_csv("../data/processed/cleaned_telco.csv", index=False)

# %% [markdown]
# # Final EDA Findings
#
# 1. The dataset contains 7043 customer records and 10 columns.
#
# 2. No missing values were found in any column.
#
# 3. No duplicate records were found.
#
# 4. The average customer tenure is approximately 32 months.
#
# 5. Only about 16% of customers are senior citizens.
#
# 6. Different internet service options are used by customers, with some services being more popular than others.
#
# 7. Online security adoption varies among customers.
